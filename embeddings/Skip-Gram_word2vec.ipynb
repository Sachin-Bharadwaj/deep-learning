# %% [markdown]
# # Skip-gram word2vec
#
# In this notebook, I'll lead you through using TensorFlow to implement the word2vec algorithm using the skip-gram architecture. By implementing this, you'll learn about embedding words for use in natural language processing. This will come in handy when dealing with things like machine translation.
#
# ## Readings
#
# Here are the resources I used to build this notebook. I suggest reading these either beforehand or while you're working on this material.
#
# * A really good [conceptual overview](http://mccormickml.com/2016/04/19/word2vec-tutorial-the-skip-gram-model/) of word2vec from Chris McCormick
# * [First word2vec paper](https://arxiv.org/pdf/1301.3781.pdf) from Mikolov et al.
# * [NIPS paper](http://papers.nips.cc/paper/5021-distributed-representations-of-words-and-phrases-and-their-compositionality.pdf) with improvements for word2vec also from Mikolov et al.
# * An [implementation of word2vec](http://www.thushv.com/natural_language_processing/word2vec-part-1-nlp-with-deep-learning-with-tensorflow-skip-gram/) from Thushan Ganegedara
# * TensorFlow [word2vec tutorial](https://www.tensorflow.org/tutorials/word2vec)
#
# ## Word embeddings
#
# When you're dealing with words in text, you end up with tens of thousands of classes to predict, one for each word. Trying to one-hot encode these words is massively inefficient, you'll have one element set to 1 and the other 50,000 set to 0. The matrix multiplication going into the first hidden layer will have almost all of the resulting values be zero. This a huge waste of computation.
#
# ![one-hot encodings](assets/one_hot_encoding.png)
#
# To solve this problem and greatly increase the efficiency of our networks, we use what are called embeddings. Embeddings are just a fully connected layer like you've seen before. We call this layer the embedding layer and the weights are embedding weights. We skip the multiplication into the embedding layer by instead directly grabbing the hidden layer values from the weight matrix. We can do this because the multiplication of a one-hot encoded vector with a matrix returns the row of the matrix corresponding the index of the "on" input unit.
#
# ![lookup](assets/lookup_matrix.png)
#
# Instead of doing the matrix multiplication, we use the weight matrix as a lookup table. We encode the words as integers, for example "heart" is encoded as 958, "mind" as 18094. Then to get hidden layer values for "heart", you just take the 958th row of the embedding matrix. This process is called an **embedding lookup** and the number of hidden units is the **embedding dimension**.
#
# <img src='assets/tokenize_lookup.png' width=500>
#
# There is nothing magical going on here. The embedding lookup table is just a weight matrix. The embedding layer is just a hidden layer. The lookup is just a shortcut for the matrix multiplication. The lookup table is trained just like any weight matrix as well.
#
# Embeddings aren't only used for words of course. You can use them for any model where you have a massive number of classes. A particular type of model called **Word2Vec** uses the embedding layer to find vector representations of words that contain semantic meaning.

# %% [markdown]
# ## Word2Vec
#
# The word2vec algorithm finds much more efficient representations by finding vectors that represent the words. These vectors also contain semantic information about the words. Words that show up in similar contexts, such as "black", "white", and "red" will have vectors near each other. There are two architectures for implementing word2vec, CBOW (Continuous Bag-Of-Words) and Skip-gram.
#
# <img src="assets/word2vec_architectures.png" width="500">
#
# In this implementation, we'll be using the skip-gram architecture because it performs better than CBOW. Here, we pass in a word and try to predict the words surrounding it in the text. In this way, we can train the network to learn representations for words that show up in similar contexts.
#
# First up, importing packages.

# %%
import time
import numpy as np
import tensorflow as tf
import utils
from urllib.request import urlretrieve
from os.path import isfile, isdir
from tqdm import tqdm
import zipfile

# %% [markdown]
# Load the [text8 dataset](http://mattmahoney.net/dc/textdata.html), a file of cleaned up Wikipedia articles from Matt Mahoney. The next cell will download the data set to the `data` folder. Then you can extract it and delete the archive file to save storage space.

# %%
dataset_folder_path = 'data'
dataset_filename = 'text8.zip'
dataset_name = 'Text8 Dataset'

class DLProgress(tqdm):
    last_block = 0

    def hook(self, block_num=1, block_size=1, total_size=None):
        self.total = total_size
        self.update((block_num - self.last_block) * block_size)
        self.last_block = block_num

if not isfile(dataset_filename):
    with DLProgress(unit='B', unit_scale=True, miniters=1, desc=dataset_name) as pbar:
        urlretrieve(
            'http://mattmahoney.net/dc/text8.zip',
            dataset_filename,
            pbar.hook)

if not isdir(dataset_folder_path):
    with zipfile.ZipFile(dataset_filename) as zip_ref:
        zip_ref.extractall(dataset_folder_path)
        
with open('data/text8') as f:
    text = f.read()

# %% [markdown]
# ## Preprocessing
#
# Here I'm fixing up the text to make training easier. This comes from the `utils` module I wrote. The `preprocess` function coverts any punctuation into tokens, so a period is changed to ` <PERIOD> `. In this data set, there aren't any periods, but it will help in other NLP problems. I'm also removing all words that show up five or fewer times in the dataset. This will greatly reduce issues due to noise in the data and improve the quality of the vector representations. If you want to write your own functions for this stuff, go for it.

# %%
words = utils.preprocess(text)
print(words[:30])
# Out:
# ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first', 'used', 'against', 'early', 'working', 'class', 'radicals', 'including', 'the', 'diggers', 'of', 'the', 'english', 'revolution', 'and', 'the', 'sans', 'culottes', 'of', 'the', 'french', 'revolution', 'whilst']

# %%
print("Total words: {}".format(len(words)))
print("Unique words: {}".format(len(set(words))))
# Out:
# Total words: 16680599
# Unique words: 63641

# %% [markdown]
# And here I'm creating dictionaries to covert words to integers and backwards, integers to words. The integers are assigned in descending frequency order, so the most frequent word ("the") is given the integer 0 and the next most frequent is 1 and so on. The words are converted to integers and stored in the list `int_words`.

# %%
vocab_to_int, int_to_vocab = utils.create_lookup_tables(words)
int_words = [vocab_to_int[word] for word in words]

# %% [markdown]
# ## Subsampling
#
# Words that show up often such as "the", "of", and "for" don't provide much context to the nearby words. If we discard some of them, we can remove some of the noise from our data and in return get faster training and better representations. This process is called subsampling by Mikolov. For each word $w_i$ in the training set, we'll discard it with probability given by
#
# $$ P(w_i) = 1 - \sqrt{\frac{t}{f(w_i)}} $$
#
# where $t$ is a threshold parameter and $f(w_i)$ is the frequency of word $w_i$ in the total dataset.
#
# I'm going to leave this up to you as an exercise. This is more of a programming challenge, than about deep learning specifically. But, being able to prepare your data for your network is an important skill to have. Check out my solution to see how I did it.
#
# > **Exercise:** Implement subsampling for the words in `int_words`. That is, go through `int_words` and discard each word given the probablility $P(w_i)$ shown above. Note that $P(w_i)$ is the probability that a word is discarded. Assign the subsampled data to `train_words`.

# %%
## Your code here
from collections import Counter
words_counts = Counter(int_words)
x               = len(int_words) # total num of words
freq = {word: float(count/x) for word,count in words_counts.items()}
print("First few prob words...")
print(list(freq.values())[0:10])
# As you can see the max prob is ~0.063, so our threshold parameter t as given in eqn above must be less than the max prob
# threshold should be chosen such that we drop max prob word with high prob (max prob word is most likely be "The", "A" which does not provide much contextual information)
# So if we choose t=1e-5, the max prob word will be dropped with probability 98.74 (very high as we want)
t = 1e-5
p_drop = {word: 1-np.sqrt(t/freq[word]) for word in words_counts}
train_words = [word for word in int_words if np.random.random() < (1 - p_drop[word])] # The final subsampled word list
# Out:
# First few prob words...
# [0.06363056866243233, 0.035590868169662254, 0.02497686084294695, 0.02468520465002486, 0.022313407330276328, 0.01953604903516954, 0.018966704972645167, 0.015885220908433802, 0.015013249823942174, 0.011548985740859786]

# %% [markdown]
# ## Making batches

# %% [markdown]
# Now that our data is in good shape, we need to get it into the proper form to pass it into our network. With the skip-gram architecture, for each word in the text, we want to grab all the words in a window around that word, with size $C$.
#
# From [Mikolov et al.](https://arxiv.org/pdf/1301.3781.pdf):
#
# "Since the more distant words are usually less related to the current word than those close to it, we give less weight to the distant words by sampling less from those words in our training examples... If we choose $C = 5$, for each training word we will select randomly a number $R$ in range $< 1; C >$, and then use $R$ words from history and $R$ words from the future of the current word as correct labels."
#
# > **Exercise:** Implement a function `get_target` that receives a list of words, an index, and a window size, then returns a list of words in the window around the index. Make sure to use the algorithm described above, where you choose a random number of words from the window.

# %%
def get_target(words, idx, window_size=5):
    ''' Get a list of words in a window around an index. 
    words: entire batch
    '''
    
    # Your code here
    R = np.random.randint(1, window_size+1)
    start_indx = idx - R if (idx - R) > 0 else 0
    stop_indx  = idx + R
    target_words = set(words[start_indx:idx] + words[idx+1:stop_indx+1])
    return list(target_words)

# %% [markdown]
# Here's a function that returns batches for our network. The idea is that it grabs `batch_size` words from a words list. Then for each of those words, it gets the target words in the window. I haven't found a way to pass in a random number of target words and get it to work with the architecture, so I make one row per input-target pair. This is a generator function by the way, helps save memory.

# %%
def get_batches(words, batch_size, window_size=5):
    ''' Create a generator of word batches as a tuple (inputs, targets) '''
    
    n_batches = len(words)//batch_size
    
    # only full batches
    words = words[:n_batches*batch_size]
    
    for idx in range(0, len(words), batch_size):
        x, y = [], []
        batch = words[idx:idx+batch_size]
        for ii in range(len(batch)):
            batch_x = batch[ii]
            batch_y = get_target(batch, ii, window_size)
            y.extend(batch_y)
            x.extend([batch_x]*len(batch_y))
        yield x, y

# %% [markdown]
# ## Building the graph
#
# From [Chris McCormick's blog](http://mccormickml.com/2016/04/19/word2vec-tutorial-the-skip-gram-model/), we can see the general structure of our network.
# ![embedding_network](./assets/skip_gram_net_arch.png)
#
# The input words are passed in as integers. This will go into a hidden layer of linear units, then into a softmax layer. We'll use the softmax layer to make a prediction like normal.
#
# The idea here is to train the hidden layer weight matrix to find efficient representations for our words. We can discard the softmax layer becuase we don't really care about making predictions with this network. We just want the embedding matrix so we can use it in other networks we build from the dataset.
#
# I'm going to have you build the graph in stages now. First off, creating the `inputs` and `labels` placeholders like normal.
#
# > **Exercise:** Assign `inputs` and `labels` using `tf.placeholder`. We're going to be passing in integers, so set the data types to `tf.int32`. The batches we're passing in will have varying sizes, so set the batch sizes to [`None`]. To make things work later, you'll need to set the second dimension of `labels` to `None` or `1`.

# %%
train_graph = tf.Graph()
with train_graph.as_default():
    inputs = tf.placeholder(tf.int32, [None], name='input')
    labels = tf.placeholder(tf.int32, [None, None], name='labels')

# %% [markdown]
# ## Embedding

# %% [markdown]
# The embedding matrix has a size of the number of words by the number of units in the hidden layer. So, if you have 10,000 words and 300 hidden units, the matrix will have size $10,000 \times 300$. Remember that we're using tokenized data for our inputs, usually as integers, where the number of tokens is the number of words in our vocabulary.
#
#
# > **Exercise:** Tensorflow provides a convenient function [`tf.nn.embedding_lookup`](https://www.tensorflow.org/api_docs/python/tf/nn/embedding_lookup) that does this lookup for us. You pass in the embedding matrix and a tensor of integers, then it returns rows in the matrix corresponding to those integers. Below, set the number of embedding features you'll use (200 is a good start), create the embedding matrix variable, and use `tf.nn.embedding_lookup` to get the embedding tensors. For the embedding matrix, I suggest you initialize it with a uniform random numbers between -1 and 1 using [tf.random_uniform](https://www.tensorflow.org/api_docs/python/tf/random_uniform).

# %%
n_vocab = len(int_to_vocab)
n_embedding =  200# Number of embedding features 
with train_graph.as_default():
    embedding = tf.Variable(tf.random_uniform((n_vocab, n_embedding), -1, 1))# create embedding weight matrix here
    embed = tf.nn.embedding_lookup(embedding, inputs)# use tf.nn.embedding_lookup to get the hidden layer output

# %% [markdown]
# ## Negative sampling

# %% [markdown]
# For every example we give the network, we train it using the output from the softmax layer. That means for each input, we're making very small changes to millions of weights even though we only have one true example. This makes training the network very inefficient. We can approximate the loss from the softmax layer by only updating a small subset of all the weights at once. We'll update the weights for the correct label, but only a small number of incorrect labels. This is called ["negative sampling"](http://papers.nips.cc/paper/5021-distributed-representations-of-words-and-phrases-and-their-compositionality.pdf). Tensorflow has a convenient function to do this, [`tf.nn.sampled_softmax_loss`](https://www.tensorflow.org/api_docs/python/tf/nn/sampled_softmax_loss).
#
# > **Exercise:** Below, create weights and biases for the softmax layer. Then, use [`tf.nn.sampled_softmax_loss`](https://www.tensorflow.org/api_docs/python/tf/nn/sampled_softmax_loss) to calculate the loss. Be sure to read the documentation to figure out how it works.

# %%
# Number of negative labels to sample
n_sampled = 100
with train_graph.as_default():
    softmax_w = tf.Variable(tf.truncated_normal((n_vocab, n_embedding), stddev=0.1))# create softmax weight matrix here
    softmax_b = tf.Variable(tf.zeros(n_vocab))# create softmax biases here
    
    # Calculate the loss using negative sampling
    loss = tf.nn.sampled_softmax_loss(softmax_w, softmax_b, labels, embed, n_sampled, n_vocab)
    
    cost = tf.reduce_mean(loss)
    optimizer = tf.train.AdamOptimizer().minimize(cost)

# %% [markdown]
# ## Validation
#
# This code is from Thushan Ganegedara's implementation. Here we're going to choose a few common words and few uncommon words. Then, we'll print out the closest words to them. It's a nice way to check that our embedding table is grouping together words with similar semantic meanings.

# %%
with train_graph.as_default():
    ## From Thushan Ganegedara's implementation
    valid_size = 16 # Random set of words to evaluate similarity on.
    valid_window = 100
    # pick 8 samples from (0,100) and (1000,1100) each ranges. lower id implies more frequent 
    valid_examples = np.array(np.random.randint(0,valid_window, valid_size//2))
    valid_examples = np.append(valid_examples, 
                               np.random.randint(1000,1000+valid_window, valid_size//2))

    valid_dataset = tf.constant(valid_examples, dtype=tf.int32)
    
    # We use the cosine distance:
    norm = tf.sqrt(tf.reduce_sum(tf.square(embedding), 1, keep_dims=True))
    normalized_embedding = embedding / norm
    valid_embedding = tf.nn.embedding_lookup(normalized_embedding, valid_dataset)
    similarity = tf.matmul(valid_embedding, tf.transpose(normalized_embedding))

# %%
# If the checkpoints directory doesn't exist:
# !mkdir checkpoints
# Out:
# mkdir: cannot create directory ‘checkpoints’: File exists

# %% [markdown]
# ## Training
#
# Below is the code to train the network. Every 100 batches it reports the training loss. Every 1000 batches, it'll print out the validation words.

# %%
epochs = 10
batch_size = 1000
window_size = 10

with train_graph.as_default():
    saver = tf.train.Saver()

with tf.Session(graph=train_graph) as sess:
    iteration = 1
    loss = 0
    sess.run(tf.global_variables_initializer())

    for e in range(1, epochs+1):
        batches = get_batches(train_words, batch_size, window_size)
        start = time.time()
        for x, y in batches:
            
            feed = {inputs: x,
                    labels: np.array(y)[:, None]}
            train_loss, _ = sess.run([cost, optimizer], feed_dict=feed)
            
            loss += train_loss
            
            if iteration % 100 == 0: 
                end = time.time()
                print("Epoch {}/{}".format(e, epochs),
                      "Iteration: {}".format(iteration),
                      "Avg. Training loss: {:.4f}".format(loss/100),
                      "{:.4f} sec/batch".format((end-start)/100))
                loss = 0
                start = time.time()
            
            if iteration % 1000 == 0:
                ## From Thushan Ganegedara's implementation
                # note that this is expensive (~20% slowdown if computed every 500 steps)
                sim = similarity.eval()
                for i in range(valid_size):
                    valid_word = int_to_vocab[valid_examples[i]]
                    top_k = 8 # number of nearest neighbors
                    nearest = (-sim[i, :]).argsort()[1:top_k+1]
                    log = 'Nearest to %s:' % valid_word
                    for k in range(top_k):
                        close_word = int_to_vocab[nearest[k]]
                        log = '%s %s,' % (log, close_word)
                    print(log)
            
            iteration += 1
    save_path = saver.save(sess, "/output/checkpoints/text8.ckpt")
    embed_mat = sess.run(normalized_embedding)
# Out:
# Epoch 1/10 Iteration: 100 Avg. Training loss: 5.6477 0.0316 sec/batch
# Epoch 1/10 Iteration: 200 Avg. Training loss: 5.5957 0.0291 sec/batch
# Epoch 1/10 Iteration: 300 Avg. Training loss: 5.5202 0.0291 sec/batch
# Epoch 1/10 Iteration: 400 Avg. Training loss: 5.5809 0.0289 sec/batch
# Epoch 1/10 Iteration: 500 Avg. Training loss: 5.4970 0.0289 sec/batch
# Epoch 1/10 Iteration: 600 Avg. Training loss: 5.5214 0.0289 sec/batch
# Epoch 1/10 Iteration: 700 Avg. Training loss: 5.5106 0.0291 sec/batch
# Epoch 1/10 Iteration: 800 Avg. Training loss: 5.5656 0.0289 sec/batch
# Epoch 1/10 Iteration: 900 Avg. Training loss: 5.4363 0.0289 sec/batch
# Epoch 1/10 Iteration: 1000 Avg. Training loss: 5.4465 0.0289 sec/batch
# Nearest to that: thatch, unimpeded, irregular, aquifers, pleadings, nesuhi, formalism, rubik,
# Nearest to between: sumitomo, pentecostals, semantic, rumored, toole, adh, skull, companionate,
# Nearest to from: sweden, dylan, unrivaled, pradesh, libration, pandemics, luminous, shar,
# Nearest to two: jacobi, hatches, banca, diario, mystic, exotic, fully, pesticides,
# Nearest to th: pb, ionospheric, wiesel, cthulhu, slave, anisotropy, widths, fidei,
# Nearest to for: communions, religous, subterranean, cracker, rsa, inverted, mauritanian, pcr,
# Nearest to b: homiletical, tail, mores, intern, lubin, santa, bulmer, peacefully,
# Nearest to war: guatemalan, ventriloquist, ribald, stricter, hypoxic, wirtschaftswunder, banca, proves,
# Nearest to alternative: elmendorf, grecian, arc, conservation, milla, depriving, dose, psychoacoustic,
# Nearest to existence: ammonia, mircea, brewers, philos, ponde, gop, kinsmen, repents,
# Nearest to active: trinitarian, ceilings, chomp, ziggurat, mollusk, atonement, wildcat, heriot,
# Nearest to pope: priority, pandemics, archduchess, original, initiated, glues, ternary, precipice,
# Nearest to question: calf, exemption, filled, rahilly, nederlandse, salla, licensing, suffragette,
# Nearest to governor: abundantly, trackball, almohades, swamps, transl, currying, regi, electronically,
# Nearest to paris: kirwan, pornography, unsurpassed, submits, paying, masoretes, padua, arcology,
# Nearest to file: iterating, plum, tattooed, hacienda, moralities, cheney, tata, canso,
# Epoch 1/10 Iteration: 1100 Avg. Training loss: 5.4894 0.0301 sec/batch
# Epoch 1/10 Iteration: 1200 Avg. Training loss: 5.3684 0.0291 sec/batch
# Epoch 1/10 Iteration: 1300 Avg. Training loss: 5.3653 0.0290 sec/batch
# Epoch 1/10 Iteration: 1400 Avg. Training loss: 5.2509 0.0289 sec/batch
# Epoch 1/10 Iteration: 1500 Avg. Training loss: 5.1914 0.0290 sec/batch
# Epoch 1/10 Iteration: 1600 Avg. Training loss: 5.1557 0.0289 sec/batch
# Epoch 1/10 Iteration: 1700 Avg. Training loss: 5.1061 0.0290 sec/batch
# Epoch 1/10 Iteration: 1800 Avg. Training loss: 5.0519 0.0290 sec/batch
# Epoch 1/10 Iteration: 1900 Avg. Training loss: 5.0213 0.0290 sec/batch
# Epoch 1/10 Iteration: 2000 Avg. Training loss: 4.9650 0.0290 sec/batch
# Nearest to that: thatch, unimpeded, towards, irregular, discuss, aquifers, course, glory,
# Nearest to between: semantic, rumored, skull, chose, location, particle, exposure, considered,
# Nearest to from: sweden, dylan, unrivaled, navy, identical, noting, term, list,
# Nearest to two: fully, hatches, exotic, banca, pesticides, jacobi, mystic, unconnected,
# Nearest to th: pb, slave, wiesel, suspension, widths, equates, cthulhu, events,
# Nearest to for: communions, subterranean, inverted, a, religous, line, attending, ft,
# Nearest to b: tail, mores, homiletical, peacefully, intern, santa, bulmer, lubin,
# Nearest to war: guatemalan, interstate, christ, take, judgment, fallout, ribald, proves,
# Nearest to alternative: conservation, elmendorf, arc, grecian, hero, mid, wetlands, depriving,
# Nearest to existence: ammonia, dark, associates, mircea, philos, structures, estimated, brewers,
# Nearest to active: trinitarian, word, atonement, equipped, ziggurat, ceilings, wildcat, lempel,
# Nearest to pope: priority, original, initiated, modify, pandemics, nfl, ternary, territorial,
# Nearest to question: filled, licensing, nederlandse, calf, exemption, dem, rahilly, salla,
# Nearest to governor: abundantly, making, trackball, electronically, clothes, transl, swamps, nelson,
# Nearest to paris: pornography, paying, kirwan, unsurpassed, masoretes, examined, submits, contributor,
# Nearest to file: iterating, plum, tattooed, there, hacienda, cheney, degrades, preoccupied,
# Epoch 1/10 Iteration: 2100 Avg. Training loss: 4.9428 0.0301 sec/batch
# Epoch 1/10 Iteration: 2200 Avg. Training loss: 4.8848 0.0291 sec/batch
# Epoch 1/10 Iteration: 2300 Avg. Training loss: 4.8710 0.0289 sec/batch
# Epoch 1/10 Iteration: 2400 Avg. Training loss: 4.8874 0.0290 sec/batch
# Epoch 1/10 Iteration: 2500 Avg. Training loss: 4.8220 0.0288 sec/batch
# Epoch 1/10 Iteration: 2600 Avg. Training loss: 4.8327 0.0290 sec/batch
# Epoch 1/10 Iteration: 2700 Avg. Training loss: 4.7896 0.0290 sec/batch
# Epoch 1/10 Iteration: 2800 Avg. Training loss: 4.7941 0.0289 sec/batch
# Epoch 1/10 Iteration: 2900 Avg. Training loss: 4.7776 0.0289 sec/batch
# Epoch 1/10 Iteration: 3000 Avg. Training loss: 4.7827 0.0291 sec/batch
# Nearest to that: discuss, towards, unimpeded, thatch, aquifers, irregular, formalism, witnesses,
# Nearest to between: semantic, rumored, particle, sumitomo, skull, pentecostals, exposure, java,
# Nearest to from: sweden, dylan, unrivaled, noting, identical, navy, luminous, spectacular,
# Nearest to two: banca, pesticides, hatches, mystic, fully, exotic, diario, pyre,
# Nearest to th: pb, slave, wiesel, maria, widths, nederland, cthulhu, ionospheric,
# Nearest to for: communions, inverted, subterranean, cracker, religous, ft, a, attending,
# Nearest to b: mores, homiletical, tail, intern, ej, lubin, peacefully, bulmer,
# Nearest to war: guatemalan, stricter, interstate, fallout, proves, christ, ribald, yugoslavian,
# Nearest to alternative: conservation, arc, elmendorf, grecian, wetlands, dose, hero, depriving,
# Nearest to existence: associates, ammonia, dark, structures, rh, estimated, depiction, guiding,
# Nearest to active: trinitarian, word, ceilings, failed, ziggurat, wash, fund, atonement,
# Nearest to pope: priority, initiated, pandemics, bobby, archduchess, modify, nfl, territorial,
# Nearest to question: filled, licensing, exemption, calf, nederlandse, rahilly, supposedly, herodotus,
# Nearest to governor: abundantly, making, clothes, electronically, transl, swamps, trackball, graphics,
# Nearest to paris: kirwan, pornography, paying, unsurpassed, examined, masoretes, submits, contributor,
# Nearest to file: plum, iterating, tattooed, cheney, there, corrientes, hacienda, degrades,
# Epoch 1/10 Iteration: 3100 Avg. Training loss: 4.7844 0.0301 sec/batch
# Epoch 1/10 Iteration: 3200 Avg. Training loss: 4.7529 0.0289 sec/batch
# Epoch 1/10 Iteration: 3300 Avg. Training loss: 4.6893 0.0290 sec/batch
# Epoch 1/10 Iteration: 3400 Avg. Training loss: 4.7214 0.0288 sec/batch
# Epoch 1/10 Iteration: 3500 Avg. Training loss: 4.7493 0.0292 sec/batch
# Epoch 1/10 Iteration: 3600 Avg. Training loss: 4.6931 0.0289 sec/batch
# Epoch 1/10 Iteration: 3700 Avg. Training loss: 4.6898 0.0291 sec/batch
# Epoch 1/10 Iteration: 3800 Avg. Training loss: 4.7160 0.0290 sec/batch
# Epoch 1/10 Iteration: 3900 Avg. Training loss: 4.7211 0.0289 sec/batch
# Epoch 1/10 Iteration: 4000 Avg. Training loss: 4.6676 0.0289 sec/batch
# Nearest to that: aquifers, formalism, towards, witnesses, thatch, unimpeded, discuss, rubik,
# Nearest to between: sumitomo, particle, companionate, pentecostals, semantic, investor, counties, skull,
# Nearest to from: sweden, unrivaled, dylan, luminous, identical, navy, linked, spectacular,
# Nearest to two: zero, banca, pesticides, hatches, mystic, pyre, migrant, helene,
# Nearest to th: pb, maria, slave, widths, wiesel, emissary, nederland, fidei,
# Nearest to for: communions, pcr, cracker, inverted, subterranean, religous, rape, rows,
# Nearest to b: homiletical, mores, lubin, statesman, tail, pei, six, intern,
# Nearest to war: guatemalan, interstate, ribald, stricter, necessities, yugoslavian, warwick, fallout,
# Nearest to alternative: grecian, elmendorf, arc, dose, conservation, wetlands, depriving, hero,
# Nearest to existence: associates, brewers, ammonia, structures, mircea, dark, rh, rules,
# Nearest to active: ceilings, trinitarian, ziggurat, word, failed, wildcat, toothpaste, loaf,
# Nearest to pope: priority, archduchess, wolff, franciszek, initiated, bobby, petition, repent,
# Nearest to question: exemption, calf, filled, licensing, rahilly, nederlandse, herodotus, storyteller,
# Nearest to governor: transl, abundantly, making, swamps, clothes, electronically, trackball, almohades,
# Nearest to paris: kirwan, pornography, unsurpassed, paying, nicolas, broderick, masoretes, sensibilities,
# Nearest to file: iterating, plum, tattooed, hacienda, corrientes, linen, preconceptions, degrades,
# Epoch 1/10 Iteration: 4100 Avg. Training loss: 4.6620 0.0300 sec/batch
# Epoch 1/10 Iteration: 4200 Avg. Training loss: 4.6428 0.0290 sec/batch
# Epoch 1/10 Iteration: 4300 Avg. Training loss: 4.6095 0.0290 sec/batch
# Epoch 1/10 Iteration: 4400 Avg. Training loss: 4.6072 0.0291 sec/batch
# Epoch 1/10 Iteration: 4500 Avg. Training loss: 4.6432 0.0289 sec/batch
# Epoch 1/10 Iteration: 4600 Avg. Training loss: 4.6412 0.0289 sec/batch
# Epoch 2/10 Iteration: 4700 Avg. Training loss: 4.6190 0.0216 sec/batch
# Epoch 2/10 Iteration: 4800 Avg. Training loss: 4.5523 0.0289 sec/batch
# Epoch 2/10 Iteration: 4900 Avg. Training loss: 4.5198 0.0291 sec/batch
# Epoch 2/10 Iteration: 5000 Avg. Training loss: 4.5016 0.0289 sec/batch
# Nearest to that: formalism, aquifers, unimpeded, towards, witnesses, discuss, thatch, yields,
# Nearest to between: sumitomo, kd, particle, universalists, semantic, investor, companionate, counties,
# Nearest to from: sweden, unrivaled, dylan, luminous, libration, hanford, hom, pandemics,
# Nearest to two: zero, banca, migrant, deluxe, three, pyre, helene, mystic,
# Nearest to th: pb, maria, widths, slave, fidei, emissary, wiesel, nederland,
# Nearest to for: cracker, communions, subterranean, bumped, pcr, inverted, and, networking,
# Nearest to b: statesman, politician, singer, lubin, six, composer, mores, homiletical,
# Nearest to war: guatemalan, interstate, ribald, stricter, yugoslavian, necessities, helena, tadeusz,
# Nearest to alternative: elmendorf, arc, dose, grecian, wetlands, conservation, depriving, exalted,
# Nearest to existence: structures, ammonia, brewers, associates, accurately, rh, mircea, dark,
# Nearest to active: ceilings, trinitarian, ziggurat, toothpaste, chomp, failed, equipped, fund,
# Nearest to pope: archduchess, priority, franciszek, bobby, heinrich, wolff, precipice, repent,
# Nearest to question: calf, exemption, filled, licensing, rahilly, nederlandse, herodotus, storyteller,
# Nearest to governor: transl, kingdom, clothes, abundantly, making, almohades, father, dublin,
# Nearest to paris: kirwan, pornography, nicolas, broderick, unsurpassed, padua, sensibilities, paying,
# Nearest to file: plum, iterating, tattooed, linen, preconceptions, hacienda, corrientes, closure,
# Epoch 2/10 Iteration: 5100 Avg. Training loss: 4.4893 0.0301 sec/batch
# Epoch 2/10 Iteration: 5200 Avg. Training loss: 4.5006 0.0290 sec/batch
# Epoch 2/10 Iteration: 5300 Avg. Training loss: 4.4811 0.0289 sec/batch
# Epoch 2/10 Iteration: 5400 Avg. Training loss: 4.5206 0.0289 sec/batch
# Epoch 2/10 Iteration: 5500 Avg. Training loss: 4.5088 0.0290 sec/batch
# Epoch 2/10 Iteration: 5600 Avg. Training loss: 4.4607 0.0289 sec/batch
# Epoch 2/10 Iteration: 5700 Avg. Training loss: 4.4596 0.0290 sec/batch
# Epoch 2/10 Iteration: 5800 Avg. Training loss: 4.4044 0.0290 sec/batch
# Epoch 2/10 Iteration: 5900 Avg. Training loss: 4.4644 0.0290 sec/batch
# Epoch 2/10 Iteration: 6000 Avg. Training loss: 4.4211 0.0289 sec/batch
# Nearest to that: aquifers, formalism, unimpeded, towards, witnesses, yields, thing, trapped,
# Nearest to between: sumitomo, kd, particle, universalists, investor, skull, municipality, counties,
# Nearest to from: unrivaled, sweden, dylan, shar, luminous, ion, trickery, swordsmen,
# Nearest to two: zero, migrant, banca, deluxe, three, median, albertosaurus, helene,
# Nearest to th: pb, maria, fidei, emissary, nederland, disproved, guerra, wiesel,
# Nearest to for: cracker, communions, networking, a, subterranean, rows, and, clones,
# Nearest to b: lubin, statesman, mores, homiletical, tail, pei, oskar, bastnasite,
# Nearest to war: guatemalan, stricter, interstate, ribald, tadeusz, army, yugoslavian, loma,
# Nearest to alternative: elmendorf, dose, arc, grecian, depriving, wetlands, conservation, milla,
# Nearest to existence: associates, structures, ammonia, brewers, acknowledge, rh, accurately, mircea,
# Nearest to active: ceilings, ziggurat, equipped, trinitarian, toothpaste, fund, failed, heriot,
# Nearest to pope: archduchess, franciszek, priority, bobby, heinrich, redistributing, instituted, yuri,
# Nearest to question: exemption, calf, rahilly, amraam, filled, salla, licensing, herodotus,
# Nearest to governor: transl, kingdom, minister, almohades, territorial, clothes, dublin, appointed,
# Nearest to paris: kirwan, pornography, nicolas, unsurpassed, broderick, sensibilities, masoretes, laika,
# Nearest to file: iterating, plum, preconceptions, closure, linen, format, corrientes, tattooed,
# Epoch 2/10 Iteration: 6100 Avg. Training loss: 4.4446 0.0302 sec/batch
# Epoch 2/10 Iteration: 6200 Avg. Training loss: 4.4520 0.0290 sec/batch
# Epoch 2/10 Iteration: 6300 Avg. Training loss: 4.4332 0.0289 sec/batch
# Epoch 2/10 Iteration: 6400 Avg. Training loss: 4.4110 0.0290 sec/batch
# Epoch 2/10 Iteration: 6500 Avg. Training loss: 4.4099 0.0290 sec/batch
# Epoch 2/10 Iteration: 6600 Avg. Training loss: 4.4337 0.0289 sec/batch
# Epoch 2/10 Iteration: 6700 Avg. Training loss: 4.3817 0.0290 sec/batch
# Epoch 2/10 Iteration: 6800 Avg. Training loss: 4.3936 0.0290 sec/batch
# Epoch 2/10 Iteration: 6900 Avg. Training loss: 4.4282 0.0289 sec/batch
# Epoch 2/10 Iteration: 7000 Avg. Training loss: 4.3726 0.0289 sec/batch
# Nearest to that: unimpeded, aquifers, towards, formalism, witnesses, thing, rubik, discuss,
# Nearest to between: sumitomo, kd, universalists, particle, skull, vilified, companionate, investor,
# Nearest to from: dylan, unrivaled, sweden, luminous, trickery, libration, hom, breed,
# Nearest to two: zero, migrant, banca, three, deluxe, median, albertosaurus, nine,
# Nearest to th: pb, maria, fidei, emissary, disproved, turan, nederland, wiesel,
# Nearest to for: communions, cracker, bumped, a, rape, inverted, rows, pcr,
# Nearest to b: lubin, statesman, mores, homiletical, tail, pei, oskar, bulmer,
# Nearest to war: ribald, tadeusz, army, guatemalan, stricter, ferret, loma, necessities,
# Nearest to alternative: dose, arc, elmendorf, milla, grecian, depriving, conservation, thermodynamic,
# Nearest to existence: associates, acknowledge, structures, resurrection, ammonia, accurately, rules, brewers,
# Nearest to active: ceilings, ziggurat, failed, chomp, fund, toothpaste, trinitarian, injurious,
# Nearest to pope: franciszek, archduchess, priority, rome, martyrs, instituted, wolff, mulatto,
# Nearest to question: exemption, calf, rahilly, amraam, filled, storyteller, transferable, salla,
# Nearest to governor: transl, kingdom, minister, appointed, dublin, territorial, tennessee, almohades,
# Nearest to paris: kirwan, nicolas, unsurpassed, pornography, broderick, arcology, laika, masoretes,
# Nearest to file: iterating, plum, format, closure, preconceptions, linen, upgraded, nike,
# Epoch 2/10 Iteration: 7100 Avg. Training loss: 4.3792 0.0299 sec/batch
# Epoch 2/10 Iteration: 7200 Avg. Training loss: 4.3962 0.0290 sec/batch
# Epoch 2/10 Iteration: 7300 Avg. Training loss: 4.3761 0.0290 sec/batch
# Epoch 2/10 Iteration: 7400 Avg. Training loss: 4.3704 0.0288 sec/batch
# Epoch 2/10 Iteration: 7500 Avg. Training loss: 4.3839 0.0289 sec/batch
# Epoch 2/10 Iteration: 7600 Avg. Training loss: 4.3626 0.0290 sec/batch
# Epoch 2/10 Iteration: 7700 Avg. Training loss: 4.3854 0.0290 sec/batch
# Epoch 2/10 Iteration: 7800 Avg. Training loss: 4.3678 0.0291 sec/batch
# Epoch 2/10 Iteration: 7900 Avg. Training loss: 4.3366 0.0290 sec/batch
# Epoch 2/10 Iteration: 8000 Avg. Training loss: 4.3325 0.0289 sec/batch
# Nearest to that: unimpeded, towards, aquifers, witnesses, formalism, thing, rubik, logically,
# Nearest to between: universalists, counties, sumitomo, kd, particle, vilified, companionate, skull,
# Nearest to from: sweden, cordell, shar, trickery, unrivaled, hom, hanford, canaan,
# Nearest to two: zero, three, migrant, four, banca, nine, mitterrand, rate,
# Nearest to th: pb, maria, fidei, nederland, disproved, emissary, turan, roman,
# Nearest to for: communions, cracker, a, and, bumped, contracts, simplification, webs,
# Nearest to b: lubin, tail, statesman, mores, pei, homiletical, oskar, algebra,
# Nearest to war: army, tadeusz, guatemalan, ribald, industrialists, defeated, concessions, loma,
# Nearest to alternative: dose, arc, thermodynamic, milla, grecian, elmendorf, symptoms, exalted,
# Nearest to existence: associates, acknowledge, structures, guiding, morals, resurrection, accurately, rules,
# Nearest to active: ceilings, ziggurat, chomp, fasa, toothpaste, failed, loaf, equipped,
# Nearest to pope: archduchess, franciszek, rome, priority, martyrs, constantinople, repent, wolff,
# Nearest to question: exemption, calf, rahilly, amraam, filled, supposedly, storyteller, salla,
# Nearest to governor: minister, dublin, transl, appointed, kingdom, almohades, carolina, tennessee,
# Nearest to paris: kirwan, nicolas, padua, broderick, unsurpassed, arcology, laika, sensibilities,
# Nearest to file: iterating, plum, format, closure, linen, upgraded, preconceptions, readers,
# Epoch 2/10 Iteration: 8100 Avg. Training loss: 4.3192 0.0301 sec/batch
# Epoch 2/10 Iteration: 8200 Avg. Training loss: 4.2986 0.0292 sec/batch
# Epoch 2/10 Iteration: 8300 Avg. Training loss: 4.3838 0.0290 sec/batch
# Epoch 2/10 Iteration: 8400 Avg. Training loss: 4.3655 0.0291 sec/batch
# Epoch 2/10 Iteration: 8500 Avg. Training loss: 4.3922 0.0290 sec/batch
# Epoch 2/10 Iteration: 8600 Avg. Training loss: 4.2810 0.0292 sec/batch
# Epoch 2/10 Iteration: 8700 Avg. Training loss: 4.3047 0.0288 sec/batch
# Epoch 2/10 Iteration: 8800 Avg. Training loss: 4.3438 0.0290 sec/batch
# Epoch 2/10 Iteration: 8900 Avg. Training loss: 4.2061 0.0291 sec/batch
# Epoch 2/10 Iteration: 9000 Avg. Training loss: 4.2946 0.0289 sec/batch
# Nearest to that: unimpeded, formalism, thing, towards, witnesses, aquifers, quantification, rubik,
# Nearest to between: kd, counties, universalists, particle, sumitomo, vilified, schengen, municipality,
# Nearest to from: hom, shar, unrivaled, hanford, sweden, cordell, trickery, libration,
# Nearest to two: zero, migrant, three, four, banca, nine, mitterrand, seven,
# Nearest to th: pb, maria, emissary, fidei, turan, disproved, roman, nederland,
# Nearest to for: communions, bumped, cracker, a, and, rows, pcr, fame,
# Nearest to b: statesman, lubin, six, mathematician, one, friedrich, botanist, giorgio,
# Nearest to war: tadeusz, army, ribald, yugoslavian, guatemalan, venizelos, industrialists, concessions,
# Nearest to alternative: arc, dose, milla, thermodynamic, grecian, elmendorf, exalted, landlord,
# Nearest to existence: acknowledge, associates, structures, guiding, manichaeism, resurrection, morals, nippur,
# Nearest to active: ceilings, ziggurat, toothpaste, loaf, bequest, failed, chomp, bibb,
# Nearest to pope: archduchess, franciszek, martyrs, rome, constantinople, priority, wolff, repent,
# Nearest to question: exemption, calf, rahilly, amraam, supposedly, filled, salla, storyteller,
# Nearest to governor: appointed, dublin, transl, minister, almohades, kingdom, tabulation, clothes,
# Nearest to paris: kirwan, nicolas, padua, sensibilities, unsurpassed, arcology, broderick, comprehensively,
# Nearest to file: iterating, plum, format, closure, linen, preconceptions, readers, developers,
# Epoch 2/10 Iteration: 9100 Avg. Training loss: 4.2964 0.0301 sec/batch
# Epoch 2/10 Iteration: 9200 Avg. Training loss: 4.2984 0.0289 sec/batch
# Epoch 3/10 Iteration: 9300 Avg. Training loss: 4.3205 0.0138 sec/batch
# Epoch 3/10 Iteration: 9400 Avg. Training loss: 4.2428 0.0290 sec/batch
# Epoch 3/10 Iteration: 9500 Avg. Training loss: 4.2338 0.0290 sec/batch
# Epoch 3/10 Iteration: 9600 Avg. Training loss: 4.2135 0.0292 sec/batch
# Epoch 3/10 Iteration: 9700 Avg. Training loss: 4.2323 0.0290 sec/batch
# Epoch 3/10 Iteration: 9800 Avg. Training loss: 4.2352 0.0291 sec/batch
# Epoch 3/10 Iteration: 9900 Avg. Training loss: 4.2440 0.0290 sec/batch
# Epoch 3/10 Iteration: 10000 Avg. Training loss: 4.1607 0.0291 sec/batch
# Nearest to that: unimpeded, towards, witnesses, thing, formalism, aquifers, trapped, quantification,
# Nearest to between: kd, sumitomo, counties, particle, municipality, location, persian, universalists,
# Nearest to from: hom, trickery, shar, cordell, altes, pradesh, canaan, conspiring,
# Nearest to two: zero, three, migrant, banca, four, seven, mitterrand, one,
# Nearest to th: pb, emissary, disproved, maria, fidei, nederland, roman, turan,
# Nearest to for: bumped, cracker, rows, communions, a, clones, ata, pcr,
# Nearest to b: statesman, lubin, mathematician, six, giorgio, botanist, oskar, one,
# Nearest to war: tadeusz, ribald, army, yugoslavian, venizelos, surrendered, eben, guatemalan,
# Nearest to alternative: milla, arc, dose, grecian, exalted, deeming, pdes, thermodynamic,
# Nearest to existence: acknowledge, associates, morals, structures, manichaeism, guiding, resurrection, euler,
# Nearest to active: ceilings, ziggurat, toothpaste, bequest, injurious, chomp, bibb, adb,
# Nearest to pope: archduchess, martyrs, franciszek, rome, constantinople, preaching, ecumenical, wolff,
# Nearest to question: exemption, calf, amraam, rahilly, filled, salla, consequences, storyteller,
# Nearest to governor: appointed, minister, almohades, dublin, transl, territorial, tabulation, tennessee,
# Nearest to paris: kirwan, nicolas, sensibilities, arcology, unsurpassed, padua, comprehensively, broderick,
# Nearest to file: iterating, format, plum, closure, preconceptions, developers, linen, upgraded,
# Epoch 3/10 Iteration: 10100 Avg. Training loss: 4.2461 0.0300 sec/batch
# Epoch 3/10 Iteration: 10200 Avg. Training loss: 4.2197 0.0289 sec/batch
# Epoch 3/10 Iteration: 10300 Avg. Training loss: 4.2358 0.0290 sec/batch
# Epoch 3/10 Iteration: 10400 Avg. Training loss: 4.1121 0.0289 sec/batch
# Epoch 3/10 Iteration: 10500 Avg. Training loss: 4.1860 0.0290 sec/batch
# Epoch 3/10 Iteration: 10600 Avg. Training loss: 4.1661 0.0289 sec/batch
# Epoch 3/10 Iteration: 10700 Avg. Training loss: 4.1860 0.0288 sec/batch
# Epoch 3/10 Iteration: 10800 Avg. Training loss: 4.1719 0.0290 sec/batch
# Epoch 3/10 Iteration: 10900 Avg. Training loss: 4.1887 0.0290 sec/batch
# Epoch 3/10 Iteration: 11000 Avg. Training loss: 4.2020 0.0289 sec/batch
# Nearest to that: unimpeded, formalism, thing, towards, witnesses, logically, aquifers, trapped,
# Nearest to between: sumitomo, kd, chromatically, particle, it, companionate, location, schengen,
# Nearest to from: hom, trickery, shar, hanford, conspiring, altes, luminous, downtempo,
# Nearest to two: zero, three, migrant, four, banca, rate, five, seven,
# Nearest to th: pb, emissary, disproved, maria, turan, nederland, roman, wiesel,
# Nearest to for: bumped, cracker, communions, rows, a, contracts, and, pcr,
# Nearest to b: algebra, statesman, lubin, bulmer, equations, interval, mathematician, oskar,
# Nearest to war: tadeusz, ribald, army, janjalani, eben, guatemalan, venizelos, surrendered,
# Nearest to alternative: milla, arc, exalted, grecian, dose, deeming, pdes, landlord,
# Nearest to existence: acknowledge, associates, structures, manichaeism, guiding, morals, euler, madox,
# Nearest to active: ceilings, ziggurat, toothpaste, injurious, bequest, bibb, failed, hairpin,
# Nearest to pope: archduchess, martyrs, rome, franciszek, preaching, ecumenical, constantinople, repent,
# Nearest to question: exemption, amraam, calf, rahilly, filled, consequences, gaffe, salla,
# Nearest to governor: appointed, almohades, minister, dublin, transl, territorial, cephalon, tabulation,
# Nearest to paris: kirwan, nicolas, unsurpassed, arcology, sensibilities, broderick, padua, recapitulation,
# Nearest to file: iterating, format, plum, closure, preconceptions, perl, nondisjunction, implement,
# Epoch 3/10 Iteration: 11100 Avg. Training loss: 4.1926 0.0300 sec/batch
# Epoch 3/10 Iteration: 11200 Avg. Training loss: 4.2147 0.0290 sec/batch
# Epoch 3/10 Iteration: 11300 Avg. Training loss: 4.1747 0.0289 sec/batch
# Epoch 3/10 Iteration: 11400 Avg. Training loss: 4.1499 0.0291 sec/batch
# Epoch 3/10 Iteration: 11500 Avg. Training loss: 4.1720 0.0290 sec/batch
# Epoch 3/10 Iteration: 11600 Avg. Training loss: 4.1939 0.0290 sec/batch
# Epoch 3/10 Iteration: 11700 Avg. Training loss: 4.1991 0.0290 sec/batch
# Epoch 3/10 Iteration: 11800 Avg. Training loss: 4.1482 0.0291 sec/batch
# Epoch 3/10 Iteration: 11900 Avg. Training loss: 4.1086 0.0290 sec/batch
# Epoch 3/10 Iteration: 12000 Avg. Training loss: 4.1969 0.0289 sec/batch
# Nearest to that: unimpeded, formalism, thing, negation, witnesses, towards, quantification, logically,
# Nearest to between: kd, sumitomo, particle, chromatically, vilified, schengen, universalists, biosafety,
# Nearest to from: hom, cordell, conspiring, altes, maxfield, trickery, hanford, luminous,
# Nearest to two: zero, three, migrant, four, nine, seven, one, rate,
# Nearest to th: pb, emissary, disproved, roman, maria, fidei, turan, nederland,
# Nearest to for: cracker, bumped, communions, rows, and, contracts, a, transferable,
# Nearest to b: statesman, lubin, oskar, algebra, mathematician, bulmer, giorgio, one,
# Nearest to war: ribald, army, janjalani, tadeusz, surrendered, eben, industrialists, venizelos,
# Nearest to alternative: milla, arc, exalted, thermodynamic, grecian, dose, pdes, deeming,
# Nearest to existence: acknowledge, associates, structures, guiding, manichaeism, morals, immutable, euler,
# Nearest to active: ceilings, ziggurat, injurious, toothpaste, bequest, hairpin, failed, bibb,
# Nearest to pope: archduchess, martyrs, franciszek, rome, ecumenical, constantinople, wolff, preaching,
# Nearest to question: exemption, amraam, calf, rahilly, filled, storyteller, gaffe, counterexample,
# Nearest to governor: appointed, minister, almohades, dublin, transl, judicial, kadyrov, atchison,
# Nearest to paris: kirwan, nicolas, unsurpassed, arcology, sensibilities, padua, comprehensively, recapitulation,
# Nearest to file: iterating, format, plum, closure, perl, gx, guis, developers,
# Epoch 3/10 Iteration: 12100 Avg. Training loss: 4.1658 0.0301 sec/batch
# Epoch 3/10 Iteration: 12200 Avg. Training loss: 4.1981 0.0292 sec/batch
# Epoch 3/10 Iteration: 12300 Avg. Training loss: 4.1620 0.0290 sec/batch
# Epoch 3/10 Iteration: 12400 Avg. Training loss: 4.1843 0.0290 sec/batch
# Epoch 3/10 Iteration: 12500 Avg. Training loss: 4.1218 0.0289 sec/batch
# Epoch 3/10 Iteration: 12600 Avg. Training loss: 4.1264 0.0290 sec/batch
# Epoch 3/10 Iteration: 12700 Avg. Training loss: 4.1677 0.0290 sec/batch
# Epoch 3/10 Iteration: 12800 Avg. Training loss: 4.1201 0.0290 sec/batch
# Epoch 3/10 Iteration: 12900 Avg. Training loss: 4.1875 0.0290 sec/batch
# Epoch 3/10 Iteration: 13000 Avg. Training loss: 4.2039 0.0290 sec/batch
# Nearest to that: unimpeded, towards, thing, witnesses, formalism, elijah, trapped, boric,
# Nearest to between: kd, sumitomo, counties, hittite, vilified, chromatically, schengen, companionate,
# Nearest to from: cordell, conspiring, canaan, hanford, altes, ministering, trickery, pradesh,
# Nearest to two: zero, three, one, four, nine, seven, eight, five,
# Nearest to th: pb, emissary, rasmussen, roman, nederland, disproved, maria, turan,
# Nearest to for: communions, cracker, and, bumped, a, gandhi, contracts, conspiring,
# Nearest to b: statesman, lubin, six, one, giorgio, mathematician, bulmer, politician,
# Nearest to war: army, tadeusz, ribald, venizelos, surrendered, industrialists, janjalani, eben,
# Nearest to alternative: milla, exalted, grecian, arc, deeming, dose, pdes, landlord,
# Nearest to existence: acknowledge, guiding, associates, structures, manichaeism, madox, immutable, morals,
# Nearest to active: ceilings, ziggurat, toothpaste, bibb, failed, injurious, bequest, hairpin,
# Nearest to pope: archduchess, martyrs, ecumenical, rome, franciszek, wolff, constantinople, preaching,
# Nearest to question: exemption, amraam, calf, filled, rahilly, gaffe, counterexample, consequences,
# Nearest to governor: appointed, almohades, minister, dublin, transl, kadyrov, dunfermline, making,
# Nearest to paris: kirwan, unsurpassed, nicolas, sensibilities, arcology, padua, leclerc, honecker,
# Nearest to file: iterating, format, plum, closure, perl, developers, directories, preconceptions,
# Epoch 3/10 Iteration: 13100 Avg. Training loss: 4.2247 0.0300 sec/batch
# Epoch 3/10 Iteration: 13200 Avg. Training loss: 4.1344 0.0291 sec/batch
# Epoch 3/10 Iteration: 13300 Avg. Training loss: 4.1467 0.0290 sec/batch
# Epoch 3/10 Iteration: 13400 Avg. Training loss: 4.1463 0.0289 sec/batch
# Epoch 3/10 Iteration: 13500 Avg. Training loss: 4.0551 0.0291 sec/batch
# Epoch 3/10 Iteration: 13600 Avg. Training loss: 4.1618 0.0291 sec/batch
# Epoch 3/10 Iteration: 13700 Avg. Training loss: 4.1497 0.0290 sec/batch
# Epoch 3/10 Iteration: 13800 Avg. Training loss: 4.1280 0.0292 sec/batch
# Epoch 4/10 Iteration: 13900 Avg. Training loss: 4.1704 0.0060 sec/batch
# Epoch 4/10 Iteration: 14000 Avg. Training loss: 4.0961 0.0290 sec/batch
# Nearest to that: thing, unimpeded, trapped, towards, formalism, witnesses, modding, elijah,
# Nearest to between: kd, sumitomo, hittite, particle, chromatically, siegfried, dangrek, biosafety,
# Nearest to from: conspiring, cordell, hom, trickery, hanford, pradesh, maxfield, altes,
# Nearest to two: zero, three, one, four, five, migrant, nine, eight,
# Nearest to th: pb, emissary, rasmussen, disproved, nd, turan, nederland, wiesel,
# Nearest to for: cracker, and, bumped, a, rows, communions, demand, pcr,
# Nearest to b: statesman, lubin, bulmer, giorgio, algebra, one, oskar, mathematician,
# Nearest to war: ribald, eben, venizelos, industrialists, tadeusz, army, contestants, janjalani,
# Nearest to alternative: milla, exalted, arc, dose, deeming, grecian, pdes, landlord,
# Nearest to existence: acknowledge, guiding, immutable, associates, euler, cosmology, morals, structures,
# Nearest to active: ceilings, ziggurat, toothpaste, injurious, bequest, bibb, hairpin, minarchism,
# Nearest to pope: archduchess, martyrs, wolff, franciszek, ecumenical, rome, maladaptive, constantinople,
# Nearest to question: amraam, exemption, calf, filled, rahilly, counterexample, gaffe, countably,
# Nearest to governor: appointed, almohades, minister, dublin, transl, dunfermline, kadyrov, tabulation,
# Nearest to paris: kirwan, sensibilities, arcology, unsurpassed, nicolas, padua, honecker, leclerc,
# Nearest to file: iterating, format, plum, closure, implement, upgraded, directories, perl,
# Epoch 4/10 Iteration: 14100 Avg. Training loss: 4.0578 0.0301 sec/batch
# Epoch 4/10 Iteration: 14200 Avg. Training loss: 4.0729 0.0290 sec/batch
# Epoch 4/10 Iteration: 14300 Avg. Training loss: 4.0815 0.0290 sec/batch
# Epoch 4/10 Iteration: 14400 Avg. Training loss: 4.0577 0.0291 sec/batch
# Epoch 4/10 Iteration: 14500 Avg. Training loss: 4.0849 0.0290 sec/batch
# Epoch 4/10 Iteration: 14600 Avg. Training loss: 4.0215 0.0290 sec/batch
# Epoch 4/10 Iteration: 14700 Avg. Training loss: 4.0874 0.0290 sec/batch
# Epoch 4/10 Iteration: 14800 Avg. Training loss: 4.0946 0.0290 sec/batch
# Epoch 4/10 Iteration: 14900 Avg. Training loss: 4.1128 0.0288 sec/batch
# Epoch 4/10 Iteration: 15000 Avg. Training loss: 4.0078 0.0290 sec/batch
# Nearest to that: thing, unimpeded, formalism, towards, witnesses, trapped, modding, elijah,
# Nearest to between: sumitomo, kd, hittite, schengen, bali, togoland, siegfried, it,
# Nearest to from: conspiring, hom, cordell, trickery, canaan, swordsmen, coterminous, encroach,
# Nearest to two: zero, three, one, four, seven, five, nine, migrant,
# Nearest to th: pb, emissary, nd, disproved, turan, rasmussen, nederland, wiesel,
# Nearest to for: a, and, cracker, rows, bumped, communions, pcr, the,
# Nearest to b: lubin, statesman, bulmer, algebra, loiter, llywelyn, giorgio, angering,
# Nearest to war: army, eben, janjalani, ribald, venizelos, industrialists, hails, spee,
# Nearest to alternative: milla, exalted, dose, deeming, arc, pdes, grecian, landlord,
# Nearest to existence: acknowledge, guiding, immutable, madox, morals, associates, manichaeism, mircea,
# Nearest to active: ceilings, ziggurat, toothpaste, injurious, hairpin, bequest, failed, adb,
# Nearest to pope: archduchess, martyrs, ecumenical, rome, martyred, franciszek, preaching, constantinople,
# Nearest to question: amraam, exemption, calf, filled, rahilly, salla, gaffe, counterexample,
# Nearest to governor: appointed, almohades, minister, dublin, tabulation, amend, legislative, judicial,
# Nearest to paris: kirwan, arcology, unsurpassed, padua, sensibilities, nicolas, comprehensively, leclerc,
# Nearest to file: iterating, format, plum, closure, upgraded, guis, preconceptions, palatable,
# Epoch 4/10 Iteration: 15100 Avg. Training loss: 4.0368 0.0301 sec/batch
# Epoch 4/10 Iteration: 15200 Avg. Training loss: 4.0733 0.0290 sec/batch
# Epoch 4/10 Iteration: 15300 Avg. Training loss: 4.0114 0.0289 sec/batch
# Epoch 4/10 Iteration: 15400 Avg. Training loss: 4.0808 0.0288 sec/batch
# Epoch 4/10 Iteration: 15500 Avg. Training loss: 4.0956 0.0290 sec/batch
# Epoch 4/10 Iteration: 15600 Avg. Training loss: 4.0366 0.0289 sec/batch
# Epoch 4/10 Iteration: 15700 Avg. Training loss: 4.0667 0.0289 sec/batch
# Epoch 4/10 Iteration: 15800 Avg. Training loss: 4.0954 0.0289 sec/batch
# Epoch 4/10 Iteration: 15900 Avg. Training loss: 4.0531 0.0291 sec/batch
# Epoch 4/10 Iteration: 16000 Avg. Training loss: 4.0575 0.0288 sec/batch
# Nearest to that: thing, unimpeded, formalism, towards, economists, logically, zermelo, negation,
# Nearest to between: kd, sumitomo, siegfried, particle, velars, chromatically, hittite, bali,
# Nearest to from: hom, conspiring, cordell, trickery, matre, wiik, monogram, workspace,
# Nearest to two: zero, three, one, four, five, seven, nine, eight,
# Nearest to th: pb, nd, emissary, disproved, rasmussen, wiesel, nederland, hutch,
# Nearest to for: and, cracker, a, rows, bumped, communions, the, demand,
# Nearest to b: statesman, lubin, bulmer, algebra, loiter, giorgio, equations, llywelyn,
# Nearest to war: eben, hails, ribald, army, janjalani, contestants, industrialists, drama,
# Nearest to alternative: exalted, milla, deeming, arc, grecian, pdes, dose, landlord,
# Nearest to existence: acknowledge, guiding, associates, immutable, cosmology, manichaeism, derivable, mircea,
# Nearest to active: ceilings, ziggurat, toothpaste, hairpin, bibb, injurious, failed, bequest,
# Nearest to pope: archduchess, ecumenical, martyrs, rome, wolff, preaching, constantinople, maladaptive,
# Nearest to question: amraam, exemption, countably, calf, filled, appropriately, counterexample, rahilly,
# Nearest to governor: appointed, almohades, minister, legislative, atchison, presides, tabulation, judicial,
# Nearest to paris: kirwan, unsurpassed, recapitulation, arcology, sensibilities, leclerc, comprehensively, nicolas,
# Nearest to file: iterating, format, plum, closure, palatable, marwan, guis, hacienda,
# Epoch 4/10 Iteration: 16100 Avg. Training loss: 4.0306 0.0299 sec/batch
# Epoch 4/10 Iteration: 16200 Avg. Training loss: 4.0873 0.0290 sec/batch
# Epoch 4/10 Iteration: 16300 Avg. Training loss: 4.0930 0.0290 sec/batch
# Epoch 4/10 Iteration: 16400 Avg. Training loss: 4.0680 0.0288 sec/batch
# Epoch 4/10 Iteration: 16500 Avg. Training loss: 4.0726 0.0290 sec/batch
# Epoch 4/10 Iteration: 16600 Avg. Training loss: 4.0736 0.0290 sec/batch
# Epoch 4/10 Iteration: 16700 Avg. Training loss: 4.0717 0.0288 sec/batch
# Epoch 4/10 Iteration: 16800 Avg. Training loss: 4.0436 0.0290 sec/batch
# Epoch 4/10 Iteration: 16900 Avg. Training loss: 4.0754 0.0291 sec/batch
# Epoch 4/10 Iteration: 17000 Avg. Training loss: 4.0785 0.0289 sec/batch
# Nearest to that: unimpeded, thing, elijah, witnesses, towards, trapped, formalism, boric,
# Nearest to between: kd, sumitomo, siegfried, togoland, biosafety, hittite, dangrek, particle,
# Nearest to from: conspiring, cordell, canaan, ministering, wiik, monogram, hom, trickery,
# Nearest to two: zero, three, one, four, seven, five, nine, eight,
# Nearest to th: nd, emissary, pb, disproved, early, nederland, rasmussen, wiesel,
# Nearest to for: and, a, communions, cracker, the, rows, conspiring, codify,
# Nearest to b: statesman, lubin, bulmer, algebra, loiter, baillie, bernhard, llywelyn,
# Nearest to war: army, janjalani, surrendered, venizelos, hails, industrialists, eben, spee,
# Nearest to alternative: exalted, milla, pdes, arc, dose, grecian, instantiated, deeming,
# Nearest to existence: acknowledge, guiding, associates, immutable, manichaeism, cosmology, structures, mircea,
# Nearest to active: ziggurat, ceilings, bibb, bequest, toothpaste, hairpin, injurious, failed,
# Nearest to pope: archduchess, ecumenical, martyrs, constantinople, rome, wolff, priority, preaching,
# Nearest to question: amraam, filled, exemption, calf, countably, gaffe, appropriately, rahilly,
# Nearest to governor: appointed, almohades, minister, judicial, atchison, legislative, amend, presides,
# Nearest to paris: kirwan, unsurpassed, recapitulation, arcology, sensibilities, leclerc, padua, nicolas,
# Nearest to file: iterating, format, plum, directories, closure, palatable, gx, bpo,
# Epoch 4/10 Iteration: 17100 Avg. Training loss: 4.0368 0.0301 sec/batch
# Epoch 4/10 Iteration: 17200 Avg. Training loss: 4.0081 0.0288 sec/batch
# Epoch 4/10 Iteration: 17300 Avg. Training loss: 4.0451 0.0290 sec/batch
# Epoch 4/10 Iteration: 17400 Avg. Training loss: 4.0538 0.0291 sec/batch
# Epoch 4/10 Iteration: 17500 Avg. Training loss: 4.0666 0.0290 sec/batch
# Epoch 4/10 Iteration: 17600 Avg. Training loss: 4.1218 0.0290 sec/batch
# Epoch 4/10 Iteration: 17700 Avg. Training loss: 4.1346 0.0289 sec/batch
# Epoch 4/10 Iteration: 17800 Avg. Training loss: 4.0393 0.0290 sec/batch
# Epoch 4/10 Iteration: 17900 Avg. Training loss: 4.0462 0.0290 sec/batch
# Epoch 4/10 Iteration: 18000 Avg. Training loss: 4.0587 0.0288 sec/batch
# Nearest to that: unimpeded, formalism, thing, economists, towards, logically, elijah, boric,
# Nearest to between: kd, siegfried, sumitomo, schengen, velars, dangrek, bali, hittite,
# Nearest to from: conspiring, cordell, trickery, hom, maxfield, monogram, swordsmen, wiik,
# Nearest to two: zero, three, one, four, seven, nine, five, six,
# Nearest to th: nd, pb, emissary, disproved, wiesel, tenth, rasmussen, nederland,
# Nearest to for: and, a, cracker, the, rows, bumped, communions, pcr,
# Nearest to b: statesman, bulmer, lubin, singer, llywelyn, gorham, vechten, baillie,
# Nearest to war: ribald, eben, army, contestants, venizelos, hails, janjalani, surrendered,
# Nearest to alternative: exalted, milla, pdes, dose, deeming, grecian, arc, landlord,
# Nearest to existence: acknowledge, guiding, mircea, hashimoto, madox, immutable, manichaeism, associates,
# Nearest to active: ziggurat, ceilings, bibb, bequest, toothpaste, injurious, hairpin, minarchism,
# Nearest to pope: archduchess, ecumenical, martyrs, constantinople, rome, wolff, maladaptive, preaching,
# Nearest to question: amraam, exemption, filled, countably, appropriately, gaffe, calf, storyteller,
# Nearest to governor: appointed, almohades, minister, atchison, mcclintock, elizabeth, dublin, amend,
# Nearest to paris: kirwan, unsurpassed, sensibilities, recapitulation, leclerc, arcology, nicolas, padua,
# Nearest to file: iterating, format, plum, closure, palatable, directories, marwan, degrades,
# Epoch 4/10 Iteration: 18100 Avg. Training loss: 3.9794 0.0300 sec/batch
# Epoch 4/10 Iteration: 18200 Avg. Training loss: 4.0351 0.0290 sec/batch
# Epoch 4/10 Iteration: 18300 Avg. Training loss: 4.0571 0.0291 sec/batch
# Epoch 4/10 Iteration: 18400 Avg. Training loss: 4.0335 0.0290 sec/batch
# Epoch 4/10 Iteration: 18500 Avg. Training loss: 4.0677 0.0289 sec/batch
# Epoch 5/10 Iteration: 18600 Avg. Training loss: 4.0482 0.0271 sec/batch
# Epoch 5/10 Iteration: 18700 Avg. Training loss: 3.9925 0.0290 sec/batch
# Epoch 5/10 Iteration: 18800 Avg. Training loss: 3.9739 0.0289 sec/batch
# Epoch 5/10 Iteration: 18900 Avg. Training loss: 4.0103 0.0290 sec/batch
# Epoch 5/10 Iteration: 19000 Avg. Training loss: 3.9633 0.0291 sec/batch
# Nearest to that: unimpeded, elijah, thing, witnesses, formalism, logically, boric, towards,
# Nearest to between: kd, sumitomo, hittite, siegfried, dangrek, velars, bali, persson,
# Nearest to from: conspiring, cordell, ministering, trickery, maxfield, hom, canaan, monogram,
# Nearest to two: zero, three, one, four, seven, five, eight, nine,
# Nearest to th: nd, emissary, pb, tenth, disproved, wiesel, events, rasmussen,
# Nearest to for: cracker, and, a, bumped, rows, pcr, the, correspondingly,
# Nearest to b: statesman, singer, gorham, llywelyn, hainaut, lubin, one, tamburlaine,
# Nearest to war: eben, ribald, army, drama, contestants, venizelos, hails, surrendered,
# Nearest to alternative: exalted, milla, dose, pdes, deeming, grecian, landlord, koenig,
# Nearest to existence: acknowledge, cosmology, guiding, immutable, manichaeism, hashimoto, derivable, mircea,
# Nearest to active: ziggurat, ceilings, toothpaste, bibb, bequest, injurious, hairpin, minarchism,
# Nearest to pope: archduchess, ecumenical, priority, wolff, maladaptive, martyrs, rome, preaching,
# Nearest to question: amraam, filled, exemption, calf, gaffe, countably, appropriately, probabilities,
# Nearest to governor: appointed, minister, almohades, amend, mcclintock, atchison, legislative, elizabeth,
# Nearest to paris: kirwan, recapitulation, unsurpassed, padua, leclerc, sensibilities, interred, arcology,
# Nearest to file: iterating, format, plum, directories, palatable, closure, implement, bpo,
# Epoch 5/10 Iteration: 19100 Avg. Training loss: 4.0157 0.0301 sec/batch
# Epoch 5/10 Iteration: 19200 Avg. Training loss: 3.9373 0.0291 sec/batch
# Epoch 5/10 Iteration: 19300 Avg. Training loss: 4.0230 0.0290 sec/batch
# Epoch 5/10 Iteration: 19400 Avg. Training loss: 4.0357 0.0289 sec/batch
# Epoch 5/10 Iteration: 19500 Avg. Training loss: 3.9938 0.0288 sec/batch
# Epoch 5/10 Iteration: 19600 Avg. Training loss: 3.9935 0.0290 sec/batch
# Epoch 5/10 Iteration: 19700 Avg. Training loss: 3.9171 0.0288 sec/batch
# Epoch 5/10 Iteration: 19800 Avg. Training loss: 3.9871 0.0289 sec/batch
# Epoch 5/10 Iteration: 19900 Avg. Training loss: 3.9536 0.0289 sec/batch
# Epoch 5/10 Iteration: 20000 Avg. Training loss: 3.9743 0.0289 sec/batch
# Nearest to that: unimpeded, elijah, thing, formalism, logically, contain, imply, not,
# Nearest to between: kd, hittite, sumitomo, theist, bali, velars, dangrek, schengen,
# Nearest to from: the, wiik, trickery, hom, with, conspiring, of, cordell,
# Nearest to two: zero, three, one, four, five, seven, nine, six,
# Nearest to th: nd, emissary, pb, tenth, early, century, disproved, wiesel,
# Nearest to for: and, a, the, cracker, pcr, bumped, rows, correspondingly,
# Nearest to b: statesman, lubin, loiter, hainaut, algebra, tamburlaine, gorham, singer,
# Nearest to war: army, eben, janjalani, contestants, surrendered, deploying, industrialists, giraldus,
# Nearest to alternative: exalted, milla, pdes, dose, deeming, grecian, koenig, landlord,
# Nearest to existence: cosmology, acknowledge, hashimoto, guiding, manichaeism, immutable, madox, derivable,
# Nearest to active: ceilings, ziggurat, toothpaste, bibb, hairpin, bequest, injurious, troposphere,
# Nearest to pope: archduchess, ecumenical, priority, wolff, maladaptive, preaching, rome, martyrs,
# Nearest to question: amraam, filled, appropriately, calf, exemption, countably, gaffe, gallup,
# Nearest to governor: appointed, minister, almohades, legislative, atchison, elizabeth, tabulation, amend,
# Nearest to paris: kirwan, recapitulation, unsurpassed, interred, france, leclerc, sensibilities, padua,
# Nearest to file: iterating, format, plum, palatable, closure, bpo, marwan, gettier,
# Epoch 5/10 Iteration: 20100 Avg. Training loss: 4.0140 0.0301 sec/batch
# Epoch 5/10 Iteration: 20200 Avg. Training loss: 3.9773 0.0289 sec/batch
# Epoch 5/10 Iteration: 20300 Avg. Training loss: 3.9382 0.0289 sec/batch
# Epoch 5/10 Iteration: 20400 Avg. Training loss: 4.0019 0.0290 sec/batch
# Epoch 5/10 Iteration: 20500 Avg. Training loss: 4.0324 0.0289 sec/batch
# Epoch 5/10 Iteration: 20600 Avg. Training loss: 3.9546 0.0289 sec/batch
# Epoch 5/10 Iteration: 20700 Avg. Training loss: 4.0159 0.0290 sec/batch
# Epoch 5/10 Iteration: 20800 Avg. Training loss: 3.9670 0.0290 sec/batch
# Epoch 5/10 Iteration: 20900 Avg. Training loss: 3.9971 0.0290 sec/batch
# Epoch 5/10 Iteration: 21000 Avg. Training loss: 3.9967 0.0288 sec/batch
# Nearest to that: unimpeded, thing, formalism, elijah, logically, imply, contain, economists,
# Nearest to between: theist, kd, hittite, velars, persson, siegfried, sumitomo, dangrek,
# Nearest to from: the, cordell, of, hom, bookrags, with, maxfield, monogram,
# Nearest to two: zero, three, one, four, five, seven, eight, nine,
# Nearest to th: nd, emissary, century, disproved, pb, tenth, early, rasmussen,
# Nearest to for: the, and, a, by, communions, cracker, pcr, codify,
# Nearest to b: statesman, singer, vechten, llywelyn, baillie, hainaut, johansson, gorham,
# Nearest to war: eben, army, contestants, giraldus, industrialists, drama, hails, deploying,
# Nearest to alternative: exalted, milla, pdes, dose, deeming, koenig, instantiated, landlord,
# Nearest to existence: cosmology, immutable, hashimoto, acknowledge, guiding, manichaeism, derivable, structures,
# Nearest to active: ceilings, bibb, ziggurat, toothpaste, hairpin, injurious, bequest, interestingly,
# Nearest to pope: archduchess, ecumenical, priority, martyrs, rome, wolff, maladaptive, malo,
# Nearest to question: amraam, appropriately, filled, gaffe, calf, gallup, storyteller, samosata,
# Nearest to governor: appointed, minister, atchison, almohades, elizabeth, mcclintock, legislative, amend,
# Nearest to paris: kirwan, recapitulation, unsurpassed, leclerc, padua, interred, france, histoire,
# Nearest to file: iterating, format, directories, plum, palatable, closure, marwan, bpo,
# Epoch 5/10 Iteration: 21100 Avg. Training loss: 4.0209 0.0300 sec/batch
# Epoch 5/10 Iteration: 21200 Avg. Training loss: 3.9889 0.0289 sec/batch
# Epoch 5/10 Iteration: 21300 Avg. Training loss: 3.9639 0.0291 sec/batch
# Epoch 5/10 Iteration: 21400 Avg. Training loss: 3.9912 0.0290 sec/batch
# Epoch 5/10 Iteration: 21500 Avg. Training loss: 4.0062 0.0291 sec/batch
# Epoch 5/10 Iteration: 21600 Avg. Training loss: 4.0019 0.0290 sec/batch
# Epoch 5/10 Iteration: 21700 Avg. Training loss: 3.9607 0.0289 sec/batch
# Epoch 5/10 Iteration: 21800 Avg. Training loss: 3.9664 0.0290 sec/batch
# Epoch 5/10 Iteration: 21900 Avg. Training loss: 3.9762 0.0288 sec/batch
# Epoch 5/10 Iteration: 22000 Avg. Training loss: 3.9990 0.0291 sec/batch
# Nearest to that: unimpeded, thing, contain, elijah, boric, logically, disavow, witnesses,
# Nearest to between: sumitomo, hittite, kd, theist, bali, siegfried, velars, vilified,
# Nearest to from: the, cordell, with, of, wiik, pandemics, fdi, canaan,
# Nearest to two: zero, three, one, four, five, eight, seven, nine,
# Nearest to th: nd, century, early, tenth, disproved, pb, emissary, rasmussen,
# Nearest to for: and, a, the, by, to, of, cracker, correspondingly,
# Nearest to b: statesman, vechten, singer, llywelyn, gorham, baillie, lubin, petr,
# Nearest to war: army, venizelos, eben, surrendered, industrialists, giraldus, contestants, janjalani,
# Nearest to alternative: exalted, milla, dose, deeming, pdes, indicating, koenig, alembic,
# Nearest to existence: hashimoto, cosmology, immutable, acknowledge, manichaeism, guiding, absurdum, derivable,
# Nearest to active: ziggurat, ceilings, bibb, hairpin, toothpaste, injurious, bequest, interestingly,
# Nearest to pope: archduchess, ecumenical, priority, martyrs, rome, preaching, maladaptive, malo,
# Nearest to question: amraam, appropriately, gaffe, gallup, filled, storyteller, probabilities, samosata,
# Nearest to governor: appointed, minister, elizabeth, atchison, almohades, colony, tabulation, kadyrov,
# ...
# Nearest to from: the, with, an, of, in, about, to, four,
# Nearest to two: zero, one, three, four, eight, five, seven, six,
# Nearest to th: century, nd, tenth, early, gaugamela, wiesel, anniversaries, pb,
# Nearest to for: and, the, a, to, of, in, by, with,
# Nearest to b: marko, singer, tamburlaine, statesman, hainaut, johansson, politician, gorham,
# Nearest to war: drama, amps, annexes, analyse, proliferation, army, ry, survivors,
# Nearest to alternative: alembic, exalted, wal, milla, pictorial, typically, indicating, deeming,
# Nearest to existence: cosmology, positrons, hashimoto, guiding, dark, morihei, deists, universe,
# Nearest to active: deployed, interestingly, sparc, fame, birdwatching, ceilings, stavropol, bulgaria,
# Nearest to pope: ecumenical, archduchess, malo, papal, innocent, maladaptive, gregory, priority,
# Nearest to question: answer, tonight, germanium, appropriately, probabilities, hmos, amraam, vancomycin,
# Nearest to governor: appointed, perak, amend, settler, gubernatorial, tabulation, minister, legislative,
# Nearest to paris: france, histoire, academie, leclerc, rot, conventual, kirwan, nationale,
# Nearest to file: format, directories, iterating, palatable, degrades, diario, archives, formats,
# Epoch 9/10 Iteration: 39100 Avg. Training loss: 3.8175 0.0301 sec/batch
# Epoch 9/10 Iteration: 39200 Avg. Training loss: 3.8595 0.0291 sec/batch
# Epoch 9/10 Iteration: 39300 Avg. Training loss: 3.8645 0.0289 sec/batch
# Epoch 9/10 Iteration: 39400 Avg. Training loss: 3.8686 0.0289 sec/batch
# Epoch 9/10 Iteration: 39500 Avg. Training loss: 3.8510 0.0288 sec/batch
# Epoch 9/10 Iteration: 39600 Avg. Training loss: 3.8767 0.0289 sec/batch
# Epoch 9/10 Iteration: 39700 Avg. Training loss: 3.8749 0.0290 sec/batch
# Epoch 9/10 Iteration: 39800 Avg. Training loss: 3.8415 0.0290 sec/batch
# Epoch 9/10 Iteration: 39900 Avg. Training loss: 3.8823 0.0290 sec/batch
# Epoch 9/10 Iteration: 40000 Avg. Training loss: 3.8589 0.0291 sec/batch
# Nearest to that: to, the, not, this, it, contain, in, of,
# Nearest to between: hercegovina, orientation, ddr, velars, centered, regularly, tarentum, multiplex,
# Nearest to from: the, with, an, of, and, in, to, about,
# Nearest to two: zero, one, three, four, five, eight, seven, six,
# Nearest to th: century, nd, tenth, early, gaugamela, centuries, anniversaries, arminius,
# Nearest to for: and, the, a, of, to, in, by, with,
# Nearest to b: marko, singer, tamburlaine, hainaut, johansson, statesman, chmielnicki, petr,
# Nearest to war: drama, army, amps, annexes, survivors, eben, wirtschaftswunder, proliferation,
# Nearest to alternative: exalted, alembic, pictorial, milla, wal, bistable, tavola, advocate,
# Nearest to existence: cosmology, positrons, hashimoto, guiding, dark, reservation, morihei, universe,
# Nearest to active: interestingly, sparc, deployed, fame, bju, bulgaria, intensify, ceilings,
# Nearest to pope: ecumenical, archduchess, malo, papal, maladaptive, priority, innocent, gregory,
# Nearest to question: answer, tonight, hmos, germanium, appropriately, obvious, weezer, coin,
# Nearest to governor: appointed, minister, amend, perak, appoint, gubernatorial, settler, chambers,
# Nearest to paris: france, histoire, academie, leclerc, nationale, rot, conventual, vien,
# Nearest to file: format, directories, iterating, palatable, degrades, diario, strict, archives,
# Epoch 9/10 Iteration: 40100 Avg. Training loss: 3.8652 0.0302 sec/batch
# Epoch 9/10 Iteration: 40200 Avg. Training loss: 3.8285 0.0289 sec/batch
# Epoch 9/10 Iteration: 40300 Avg. Training loss: 3.8122 0.0291 sec/batch
# Epoch 9/10 Iteration: 40400 Avg. Training loss: 3.8572 0.0289 sec/batch
# Epoch 9/10 Iteration: 40500 Avg. Training loss: 3.9023 0.0291 sec/batch
# Epoch 9/10 Iteration: 40600 Avg. Training loss: 3.8647 0.0292 sec/batch
# Epoch 9/10 Iteration: 40700 Avg. Training loss: 3.9737 0.0289 sec/batch
# Epoch 9/10 Iteration: 40800 Avg. Training loss: 3.8864 0.0289 sec/batch
# Epoch 9/10 Iteration: 40900 Avg. Training loss: 3.9295 0.0290 sec/batch
# Epoch 9/10 Iteration: 41000 Avg. Training loss: 3.8234 0.0289 sec/batch
# Nearest to that: to, the, not, it, this, in, with, of,
# Nearest to between: hercegovina, velars, there, orientation, incubated, ddr, hive, contextual,
# Nearest to from: the, with, an, of, and, in, about, to,
# Nearest to two: zero, one, three, four, five, eight, seven, nine,
# Nearest to th: century, tenth, nd, early, gaugamela, centuries, continued, mid,
# Nearest to for: and, the, a, of, in, to, by, with,
# Nearest to b: marko, singer, statesman, tamburlaine, hainaut, chmielnicki, gorham, maniera,
# Nearest to war: drama, gunboat, army, amps, annexes, analyse, venizelos, eben,
# Nearest to alternative: alembic, exalted, wal, tavola, deeming, alternatives, pictorial, typically,
# Nearest to existence: cosmology, hashimoto, positrons, guiding, signatories, reservation, morihei, pandering,
# Nearest to active: interestingly, deployed, bulgaria, bju, sparc, fame, stavropol, intensify,
# Nearest to pope: ecumenical, archduchess, papal, malo, maladaptive, innocent, priority, gregory,
# Nearest to question: answer, tonight, appropriately, germanium, hmos, probabilities, it, eccl,
# Nearest to governor: appointed, perak, brentano, amend, chambers, settler, gubernatorial, soros,
# Nearest to paris: france, histoire, academie, nationale, rot, leclerc, montparnasse, conventual,
# Nearest to file: directories, format, iterating, palatable, degrades, diario, strict, hacienda,
# Epoch 9/10 Iteration: 41100 Avg. Training loss: 3.7998 0.0300 sec/batch
# Epoch 9/10 Iteration: 41200 Avg. Training loss: 3.8665 0.0289 sec/batch
# Epoch 9/10 Iteration: 41300 Avg. Training loss: 3.7741 0.0292 sec/batch
# Epoch 9/10 Iteration: 41400 Avg. Training loss: 3.8689 0.0290 sec/batch
# Epoch 9/10 Iteration: 41500 Avg. Training loss: 3.8348 0.0290 sec/batch
# Epoch 9/10 Iteration: 41600 Avg. Training loss: 3.8430 0.0289 sec/batch
# Epoch 10/10 Iteration: 41700 Avg. Training loss: 3.8777 0.0170 sec/batch
# Epoch 10/10 Iteration: 41800 Avg. Training loss: 3.8179 0.0290 sec/batch
# Epoch 10/10 Iteration: 41900 Avg. Training loss: 3.8275 0.0289 sec/batch
# Epoch 10/10 Iteration: 42000 Avg. Training loss: 3.8633 0.0290 sec/batch
# Nearest to that: to, the, not, in, it, claimed, this, with,
# Nearest to between: velars, centered, orientation, hercegovina, hittite, is, anglia, ddr,
# Nearest to from: the, with, an, of, in, to, about, and,
# Nearest to two: zero, one, three, four, five, eight, seven, six,
# Nearest to th: century, tenth, nd, early, gaugamela, centuries, anniversaries, arminius,
# Nearest to for: and, the, a, of, in, to, by, with,
# Nearest to b: singer, statesman, marko, gorham, tamburlaine, chmielnicki, petr, composer,
# Nearest to war: drama, annexes, gunboat, amps, davidson, tailored, ry, eben,
# Nearest to alternative: alembic, exalted, pictorial, alternatives, milla, wal, advocate, tavola,
# Nearest to existence: cosmology, positrons, hashimoto, guiding, signatories, immutable, pandering, deists,
# Nearest to active: interestingly, bulgaria, bju, fame, stavropol, intensify, deployed, sparc,
# Nearest to pope: archduchess, malo, papal, ecumenical, innocent, maladaptive, priority, contaminated,
# Nearest to question: answer, tonight, hmos, germanium, appropriately, amraam, questions, obvious,
# Nearest to governor: appointed, amend, perak, brentano, gubernatorial, chambers, legislative, soros,
# Nearest to paris: france, histoire, academie, nationale, rot, leclerc, conventual, brash,
# Nearest to file: directories, format, iterating, palatable, diario, strict, hacienda, degrades,
# Epoch 10/10 Iteration: 42100 Avg. Training loss: 3.8376 0.0302 sec/batch
# Epoch 10/10 Iteration: 42200 Avg. Training loss: 3.8268 0.0290 sec/batch
# Epoch 10/10 Iteration: 42300 Avg. Training loss: 3.8377 0.0291 sec/batch
# Epoch 10/10 Iteration: 42400 Avg. Training loss: 3.7949 0.0290 sec/batch
# Epoch 10/10 Iteration: 42500 Avg. Training loss: 3.8289 0.0289 sec/batch
# Epoch 10/10 Iteration: 42600 Avg. Training loss: 3.8354 0.0289 sec/batch
# Epoch 10/10 Iteration: 42700 Avg. Training loss: 3.8676 0.0289 sec/batch
# Epoch 10/10 Iteration: 42800 Avg. Training loss: 3.7496 0.0291 sec/batch
# Epoch 10/10 Iteration: 42900 Avg. Training loss: 3.8129 0.0289 sec/batch
# Epoch 10/10 Iteration: 43000 Avg. Training loss: 3.7967 0.0289 sec/batch
# Nearest to that: to, the, this, of, in, it, not, which,
# Nearest to between: hercegovina, centered, orientation, the, velars, of, is, it,
# Nearest to from: the, with, an, in, and, of, about, to,
# Nearest to two: zero, one, three, four, five, eight, seven, six,
# Nearest to th: century, tenth, nd, early, gaugamela, centuries, anniversaries, nfc,
# Nearest to for: and, a, the, of, in, to, by, is,
# Nearest to b: intercept, marko, statesman, awd, follows, maniera, tamburlaine, gorham,
# Nearest to war: drama, amps, annexes, tailored, gunboat, analyse, davidson, eben,
# Nearest to alternative: exalted, alembic, pictorial, wal, alternatives, milla, usage, advocate,
# Nearest to existence: cosmology, positrons, hashimoto, guiding, reservation, signatories, pandering, vedanta,
# Nearest to active: deployed, fame, bulgaria, interestingly, stavropol, bju, sparc, intensify,
# Nearest to pope: archduchess, malo, ecumenical, papal, innocent, maladaptive, gregory, contaminated,
# Nearest to question: answer, germanium, tonight, hmos, appropriately, ruling, probabilities, vancomycin,
# Nearest to governor: appointed, legislative, perak, amend, gubernatorial, soros, brentano, chambers,
# Nearest to paris: france, histoire, academie, nationale, rot, leclerc, conventual, maison,
# Nearest to file: directories, format, iterating, diario, palatable, degrades, hacienda, strict,
# Epoch 10/10 Iteration: 43100 Avg. Training loss: 3.7236 0.0300 sec/batch
# Epoch 10/10 Iteration: 43200 Avg. Training loss: 3.8388 0.0291 sec/batch
# Epoch 10/10 Iteration: 43300 Avg. Training loss: 3.8568 0.0290 sec/batch
# Epoch 10/10 Iteration: 43400 Avg. Training loss: 3.8126 0.0289 sec/batch
# Epoch 10/10 Iteration: 43500 Avg. Training loss: 3.8404 0.0289 sec/batch
# Epoch 10/10 Iteration: 43600 Avg. Training loss: 3.9011 0.0289 sec/batch
# Epoch 10/10 Iteration: 43700 Avg. Training loss: 3.8607 0.0290 sec/batch
# Epoch 10/10 Iteration: 43800 Avg. Training loss: 3.8175 0.0289 sec/batch
# Epoch 10/10 Iteration: 43900 Avg. Training loss: 3.8205 0.0289 sec/batch
# Epoch 10/10 Iteration: 44000 Avg. Training loss: 3.8415 0.0290 sec/batch
# Nearest to that: to, the, of, it, this, in, not, contain,
# Nearest to between: orientation, ddr, hercegovina, centered, as, hive, multiplex, velars,
# Nearest to from: the, with, an, in, and, of, to, four,
# Nearest to two: zero, one, three, four, five, eight, seven, nine,
# Nearest to th: century, nd, tenth, early, gaugamela, centuries, anniversaries, arminius,
# Nearest to for: and, the, a, of, in, to, by, with,
# Nearest to b: marko, statesman, awd, intercept, tamburlaine, johansson, infinitely, gorham,
# Nearest to war: drama, analyse, annexes, amps, tailored, proliferation, gunboat, eben,
# Nearest to alternative: exalted, alembic, wal, alternatives, advocate, pictorial, usage, typically,
# Nearest to existence: positrons, hashimoto, cosmology, guiding, reservation, signatories, immutable, morihei,
# Nearest to active: deployed, bju, stavropol, bulgaria, interestingly, fame, sparc, intensify,
# Nearest to pope: archduchess, malo, papal, ecumenical, innocent, maladaptive, xiii, pius,
# Nearest to question: answer, germanium, hmos, appropriately, eccl, tonight, obvious, ruling,
# Nearest to governor: appointed, gubernatorial, legislative, soros, perak, amend, brentano, dimming,
# Nearest to paris: france, histoire, academie, nationale, rot, leclerc, maison, conventual,
# Nearest to file: directories, format, iterating, diario, palatable, degrades, strict, hacienda,
# Epoch 10/10 Iteration: 44100 Avg. Training loss: 3.8529 0.0300 sec/batch
# Epoch 10/10 Iteration: 44200 Avg. Training loss: 3.8603 0.0289 sec/batch
# Epoch 10/10 Iteration: 44300 Avg. Training loss: 3.8048 0.0290 sec/batch
# Epoch 10/10 Iteration: 44400 Avg. Training loss: 3.8226 0.0289 sec/batch
# Epoch 10/10 Iteration: 44500 Avg. Training loss: 3.8751 0.0289 sec/batch
# Epoch 10/10 Iteration: 44600 Avg. Training loss: 3.8348 0.0291 sec/batch
# Epoch 10/10 Iteration: 44700 Avg. Training loss: 3.8327 0.0291 sec/batch
# Epoch 10/10 Iteration: 44800 Avg. Training loss: 3.8136 0.0289 sec/batch
# Epoch 10/10 Iteration: 44900 Avg. Training loss: 3.7555 0.0289 sec/batch
# Epoch 10/10 Iteration: 45000 Avg. Training loss: 3.8271 0.0290 sec/batch
# Nearest to that: to, the, it, in, this, of, not, is,
# Nearest to between: the, orientation, nine, as, of, hercegovina, and, is,
# Nearest to from: the, with, and, an, in, of, to, four,
# Nearest to two: one, zero, three, four, five, eight, nine, seven,
# Nearest to th: century, tenth, nd, early, centuries, gaugamela, arminius, nfc,
# Nearest to for: and, the, a, to, of, in, with, by,
# Nearest to b: marko, awd, intercept, reexports, maniera, infinitely, tamburlaine, statesman,
# Nearest to war: fought, army, drama, annexes, gunboat, venizelos, treaty, industrialists,
# Nearest to alternative: exalted, alembic, wal, alternatives, usage, typically, advocate, bistable,
# Nearest to existence: positrons, cosmology, hashimoto, guiding, reservation, signatories, instantaneous, undermines,
# Nearest to active: deployed, fame, interestingly, bju, sparc, stavropol, bulgaria, alessandro,
# Nearest to pope: papal, archduchess, malo, ecumenical, innocent, xiii, maladaptive, shilling,
# Nearest to question: answer, hmos, germanium, tonight, appropriately, obvious, eccl, probabilities,
# Nearest to governor: appointed, gubernatorial, perak, amend, legislative, chambers, soros, fante,
# Nearest to paris: france, academie, nationale, histoire, leclerc, conventual, maison, rot,
# Nearest to file: directories, format, iterating, diario, palatable, strict, degrades, formats,
# Epoch 10/10 Iteration: 45100 Avg. Training loss: 3.8728 0.0301 sec/batch
# Epoch 10/10 Iteration: 45200 Avg. Training loss: 3.8172 0.0291 sec/batch
# Epoch 10/10 Iteration: 45300 Avg. Training loss: 3.9193 0.0290 sec/batch
# Epoch 10/10 Iteration: 45400 Avg. Training loss: 3.9295 0.0290 sec/batch
# Epoch 10/10 Iteration: 45500 Avg. Training loss: 3.8871 0.0289 sec/batch
# Epoch 10/10 Iteration: 45600 Avg. Training loss: 3.8295 0.0290 sec/batch
# Epoch 10/10 Iteration: 45700 Avg. Training loss: 3.7821 0.0289 sec/batch
# Epoch 10/10 Iteration: 45800 Avg. Training loss: 3.8451 0.0289 sec/batch
# Epoch 10/10 Iteration: 45900 Avg. Training loss: 3.6782 0.0291 sec/batch
# Epoch 10/10 Iteration: 46000 Avg. Training loss: 3.8531 0.0290 sec/batch
# Nearest to that: to, the, it, of, in, not, which, this,
# Nearest to between: the, orientation, as, velars, ddr, hercegovina, of, centered,
# Nearest to from: the, with, an, in, of, and, to, about,
# Nearest to two: zero, one, three, four, five, eight, nine, seven,
# Nearest to th: century, tenth, nd, early, centuries, gaugamela, anniversary, anniversaries,
# Nearest to for: and, a, the, to, of, in, with, by,
# Nearest to b: marko, statesman, singer, gorham, awd, hainaut, petr, tamburlaine,
# Nearest to war: annexes, drama, analyse, foxx, treaty, fought, tailored, amps,
# Nearest to alternative: exalted, alembic, wal, alternatives, tavola, usage, pictorial, typically,
# Nearest to existence: positrons, hashimoto, cosmology, guiding, signatories, reservation, pandering, morihei,
# Nearest to active: bju, fame, bulgaria, stavropol, interestingly, alessandro, sparc, deployed,
# Nearest to pope: papal, archduchess, malo, ecumenical, innocent, xiii, maladaptive, pius,
# Nearest to question: answer, germanium, hmos, appropriately, eccl, questions, tonight, coin,
# Nearest to governor: appointed, gubernatorial, perak, soros, amend, brentano, fante, legislative,
# Nearest to paris: france, academie, histoire, nationale, leclerc, maison, conventual, centrale,
# Nearest to file: directories, format, iterating, diario, palatable, strict, lossless, degrades,
# Epoch 10/10 Iteration: 46100 Avg. Training loss: 3.8485 0.0301 sec/batch
# Epoch 10/10 Iteration: 46200 Avg. Training loss: 3.8252 0.0290 sec/batch

# %% [markdown]
# Restore the trained network if you need to:

# %%
with train_graph.as_default():
    saver = tf.train.Saver()

with tf.Session(graph=train_graph) as sess:
    saver.restore(sess, tf.train.latest_checkpoint('/output/checkpoints'))
    embed_mat = sess.run(embedding)
# Out:
# INFO:tensorflow:Restoring parameters from /output/checkpoints/text8.ckpt

# %% [markdown]
# ## Visualizing the word vectors
#
# Below we'll use T-SNE to visualize how our high-dimensional word vectors cluster together. T-SNE is used to project these vectors into two dimensions while preserving local stucture. Check out [this post from Christopher Olah](http://colah.github.io/posts/2014-10-Visualizing-MNIST/) to learn more about T-SNE and other ways to visualize high-dimensional data.

# %%
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

import matplotlib.pyplot as plt
from sklearn.manifold import TSNE

# %%
viz_words = 1000
tsne = TSNE()
embed_tsne = tsne.fit_transform(embed_mat[:viz_words, :])

# %%
fig, ax = plt.subplots(figsize=(14, 14))
for idx in range(viz_words):
    plt.scatter(*embed_tsne[idx, :], color='steelblue')
    plt.annotate(int_to_vocab[idx], (embed_tsne[idx, 0], embed_tsne[idx, 1]), alpha=0.7)
